# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data/bank-full.csv", sep=";")
data.shape
# Out:
# (45211, 17)

# %%
y =data['y']
y = y.map(lambda x: 0 if x=="no" else 1)
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: y, dtype: int64

# %%
data.isnull().any()
# Out:
# age          False
# job          False
# marital      False
# education    False
# default      False
# balance      False
# housing      False
# loan         False
# contact      False
# day          False
# month        False
# duration     False
# campaign     False
# pdays        False
# previous     False
# poutcome     False
# y            False
# dtype: bool

# %%
data.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
numeric_features= list(data.columns[data.dtypes == 'int64'])
data[numeric_features] = data[numeric_features].astype(float)

# %%
data.head()
# Out:
#     age           job  marital  education default  balance housing loan  \
# 0  58.0    management  married   tertiary      no   2143.0     yes   no
# 1  44.0    technician   single  secondary      no     29.0     yes   no
# 2  33.0  entrepreneur  married  secondary      no      2.0     yes  yes
# 3  47.0   blue-collar  married    unknown      no   1506.0     yes   no
# 4  33.0       unknown   single    unknown      no      1.0      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown  5.0   may     261.0       1.0   -1.0       0.0  unknown  no
# 1  unknown  5.0   may     151.0       1.0   -1.0       0.0  unknown  no
# 2  unknown  5.0   may      76.0       1.0   -1.0       0.0  unknown  no
# 3  unknown  5.0   may      92.0       1.0   -1.0       0.0  unknown  no
# 4  unknown  5.0   may     198.0       1.0   -1.0       0.0  unknown  no

# %%
data.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       -1.000000      0.000000
# max      871.000000    275.000000

# %%
data.loc[data["y"]=="yes"]
# Out:
#         age            job   marital  education default  balance housing loan  \
# 83     59.0         admin.   married  secondary      no   2343.0     yes   no
# 86     56.0         admin.   married  secondary      no     45.0      no   no
# 87     41.0     technician   married  secondary      no   1270.0     yes   no
# 129    55.0       services   married  secondary      no   2476.0     yes   no
# 168    54.0         admin.   married   tertiary      no    184.0      no   no
# 270    42.0     management    single   tertiary      no      0.0     yes  yes
# 388    56.0     management   married   tertiary      no    830.0     yes  yes
# 390    60.0        retired  divorced  secondary      no    545.0     yes   no
# 446    39.0     technician    single    unknown      no  45248.0     yes   no
# 457    37.0     technician   married  secondary      no      1.0     yes   no
# 474    34.0         admin.   married  secondary      no    869.0      no   no
# 512    55.0     unemployed  divorced  secondary      no    387.0     yes   no
# 569    28.0       services    single  secondary      no   5090.0     yes   no
# 624    30.0     technician   married  secondary      no    484.0     yes   no
# 694    36.0     technician   married  secondary      no    368.0     yes  yes
# 849    37.0         admin.    single  secondary      no    245.0     yes  yes
# 877    45.0    blue-collar   married  secondary      no    154.0     yes   no
# 891    53.0       services  divorced    primary      no   -291.0     yes  yes
# 897    38.0         admin.    single  secondary      no    100.0     yes   no
# 1087   30.0    blue-collar   married  secondary      no    309.0     yes   no
# 1124   29.0     management   married   tertiary      no    199.0     yes  yes
# 1140   46.0    blue-collar    single   tertiary      no    460.0     yes   no
# 1172   31.0     technician    single   tertiary      no    703.0     yes   no
# 1173   39.0    blue-collar   married    primary      no     70.0      no   no
# 1193   35.0     management  divorced   tertiary      no   3837.0     yes   no
# 1200   32.0    blue-collar    single    primary      no    611.0     yes   no
# 1247   49.0       services   married  secondary      no     -8.0     yes   no
# 1273   41.0         admin.   married  secondary      no     55.0     yes   no
# 1340   49.0         admin.  divorced  secondary      no    168.0     yes  yes
# 1370   28.0         admin.  divorced  secondary      no    785.0     yes   no
# ...     ...            ...       ...        ...     ...      ...     ...  ...
# 45157  52.0     technician   married   tertiary      no      0.0      no   no
# 45160  35.0     technician   married  secondary      no      0.0     yes   no
# 45162  29.0         admin.    single  secondary      no    464.0      no   no
# 45166  41.0     unemployed    single   tertiary      no     79.0      no   no
# 45168  62.0        retired   married   tertiary      no   2557.0     yes   no
# 45174  62.0    blue-collar   married  secondary      no    272.0      no   no
# 45175  38.0   entrepreneur    single  secondary      no   2543.0      no   no
# 45176  54.0         admin.   married  secondary      no     66.0     yes   no
# 45177  36.0         admin.  divorced  secondary      no   1224.0     yes   no
# 45178  34.0    blue-collar   married  secondary      no    320.0     yes   no
# 45182  34.0     technician   married  secondary      no    133.0      no   no
# 45185  60.0       services   married   tertiary      no   4256.0     yes   no
# 45187  32.0       services    single  secondary      no   1168.0     yes   no
# 45188  29.0     management    single  secondary      no    703.0     yes   no
# 45190  32.0    blue-collar   married  secondary      no    136.0      no   no
# 45191  75.0        retired  divorced   tertiary      no   3810.0     yes   no
# 45192  29.0     management    single   tertiary      no    765.0      no   no
# 45193  28.0  self-employed    single   tertiary      no    159.0      no   no
# 45195  68.0        retired   married  secondary      no   1146.0      no   no
# 45196  25.0        student    single  secondary      no    358.0      no   no
# 45197  36.0     management    single  secondary      no   1511.0     yes   no
# 45200  38.0     technician   married  secondary      no    557.0     yes   no
# 45201  53.0     management   married   tertiary      no    583.0      no   no
# 45202  34.0         admin.    single  secondary      no    557.0      no   no
# 45203  23.0        student    single   tertiary      no    113.0      no   no
# 45204  73.0        retired   married  secondary      no   2850.0      no   no
# 45205  25.0     technician    single  secondary      no    505.0      no  yes
# 45206  51.0     technician   married   tertiary      no    825.0      no   no
# 45207  71.0        retired  divorced    primary      no   1729.0      no   no
# 45208  72.0        retired   married  secondary      no   5715.0      no   no
#
#          contact   day month  duration  campaign  pdays  previous poutcome  \
# 83       unknown   5.0   may    1042.0       1.0   -1.0       0.0  unknown
# 86       unknown   5.0   may    1467.0       1.0   -1.0       0.0  unknown
# 87       unknown   5.0   may    1389.0       1.0   -1.0       0.0  unknown
# 129      unknown   5.0   may     579.0       1.0   -1.0       0.0  unknown
# 168      unknown   5.0   may     673.0       2.0   -1.0       0.0  unknown
# 270      unknown   5.0   may     562.0       2.0   -1.0       0.0  unknown
# 388      unknown   6.0   may    1201.0       1.0   -1.0       0.0  unknown
# 390      unknown   6.0   may    1030.0       1.0   -1.0       0.0  unknown
# 446      unknown   6.0   may    1623.0       1.0   -1.0       0.0  unknown
# 457      unknown   6.0   may     608.0       1.0   -1.0       0.0  unknown
# 474      unknown   6.0   may    1677.0       1.0   -1.0       0.0  unknown
# 512      unknown   6.0   may     918.0       1.0   -1.0       0.0  unknown
# 569      unknown   6.0   may    1297.0       3.0   -1.0       0.0  unknown
# 624      unknown   6.0   may     703.0       1.0   -1.0       0.0  unknown
# 694      unknown   6.0   may    1597.0       2.0   -1.0       0.0  unknown
# 849      unknown   7.0   may     732.0       2.0   -1.0       0.0  unknown
# 877      unknown   7.0   may    1138.0       1.0   -1.0       0.0  unknown
# 891      unknown   7.0   may     591.0       1.0   -1.0       0.0  unknown
# 897      unknown   7.0   may     786.0       1.0   -1.0       0.0  unknown
# 1087     unknown   7.0   may    1574.0       2.0   -1.0       0.0  unknown
# 1124     unknown   7.0   may    1689.0       4.0   -1.0       0.0  unknown
# 1140     unknown   7.0   may    1102.0       2.0   -1.0       0.0  unknown
# 1172     unknown   8.0   may     943.0       2.0   -1.0       0.0  unknown
# 1173     unknown   8.0   may     813.0       1.0   -1.0       0.0  unknown
# 1193     unknown   8.0   may    1084.0       1.0   -1.0       0.0  unknown
# 1200     unknown   8.0   may     541.0       3.0   -1.0       0.0  unknown
# 1247     unknown   8.0   may    1119.0       1.0   -1.0       0.0  unknown
# 1273     unknown   8.0   may    1120.0       2.0   -1.0       0.0  unknown
# 1340     unknown   8.0   may     513.0       1.0   -1.0       0.0  unknown
# 1370     unknown   8.0   may     442.0       2.0   -1.0       0.0  unknown
# ...          ...   ...   ...       ...       ...    ...       ...      ...
# 45157   cellular   9.0   nov     467.0       3.0   92.0       7.0  failure
# 45160   cellular   9.0   nov     524.0       1.0   96.0       5.0  success
# 45162   cellular   9.0   nov     208.0       2.0   91.0       3.0  success
# 45166  telephone   9.0   nov     394.0       1.0  390.0       2.0  success
# 45168   cellular  10.0   nov     404.0       1.0   57.0       8.0  success
# 45174   cellular  11.0   nov     289.0       1.0   92.0       3.0  success
# 45175   cellular  11.0   nov     357.0       3.0   93.0       5.0  success
# 45176   cellular  11.0   nov     167.0       1.0   -1.0       0.0  unknown
# 45177   cellular  12.0   nov     482.0       1.0  374.0       1.0  success
# 45178   cellular  12.0   nov     413.0       1.0   92.0       3.0  success
# 45182   cellular  15.0   nov     401.0       2.0  187.0       5.0  success
# 45185   cellular  16.0   nov     200.0       1.0   92.0       4.0  success
# 45187   cellular  16.0   nov     411.0       1.0   -1.0       0.0  unknown
# 45188   cellular  16.0   nov     236.0       1.0  550.0       2.0  success
# 45190   cellular  16.0   nov     206.0       1.0  188.0       3.0  success
# 45191   cellular  16.0   nov     262.0       1.0  183.0       1.0  failure
# 45192   cellular  16.0   nov     238.0       1.0   -1.0       0.0  unknown
# 45193   cellular  16.0   nov     449.0       2.0   33.0       4.0  success
# 45195   cellular  16.0   nov     212.0       1.0  187.0       6.0  success
# 45196   cellular  16.0   nov     330.0       1.0   -1.0       0.0  unknown
# 45197   cellular  16.0   nov     270.0       1.0   -1.0       0.0  unknown
# 45200   cellular  16.0   nov    1556.0       4.0   -1.0       0.0  unknown
# 45201   cellular  17.0   nov     226.0       1.0  184.0       4.0  success
# 45202   cellular  17.0   nov     224.0       1.0   -1.0       0.0  unknown
# 45203   cellular  17.0   nov     266.0       1.0   -1.0       0.0  unknown
# 45204   cellular  17.0   nov     300.0       1.0   40.0       8.0  failure
# 45205   cellular  17.0   nov     386.0       2.0   -1.0       0.0  unknown
# 45206   cellular  17.0   nov     977.0       3.0   -1.0       0.0  unknown
# 45207   cellular  17.0   nov     456.0       2.0   -1.0       0.0  unknown
# 45208   cellular  17.0   nov    1127.0       5.0  184.0       3.0  success
#
#          y
# 83     yes
# 86     yes
# 87     yes
# 129    yes
# 168    yes
# 270    yes
# 388    yes
# 390    yes
# 446    yes
# 457    yes
# 474    yes
# 512    yes
# 569    yes
# 624    yes
# 694    yes
# 849    yes
# 877    yes
# 891    yes
# 897    yes
# 1087   yes
# 1124   yes
# 1140   yes
# 1172   yes
# 1173   yes
# 1193   yes
# 1200   yes
# 1247   yes
# 1273   yes
# 1340   yes
# 1370   yes
# ...    ...
# 45157  yes
# 45160  yes
# 45162  yes
# 45166  yes
# 45168  yes
# 45174  yes
# 45175  yes
# 45176  yes
# 45177  yes
# 45178  yes
# 45182  yes
# 45185  yes
# 45187  yes
# 45188  yes
# 45190  yes
# 45191  yes
# 45192  yes
# 45193  yes
# 45195  yes
# 45196  yes
# 45197  yes
# 45200  yes
# 45201  yes
# 45202  yes
# 45203  yes
# 45204  yes
# 45205  yes
# 45206  yes
# 45207  yes
# 45208  yes
#
# [5289 rows x 17 columns]

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
for c in data.columns:
    if data[c].dtype == "object":
        print("#",c)
        print(data[c].unique())
        print("")
# Out:
# # job
# ['management' 'technician' 'entrepreneur' 'blue-collar' 'unknown'
#  'retired' 'admin.' 'services' 'self-employed' 'unemployed' 'housemaid'
#  'student']
#
# # marital
# ['married' 'single' 'divorced']
#
# # education
# ['tertiary' 'secondary' 'unknown' 'primary']
#
# # default
# ['no' 'yes']
#
# # housing
# ['yes' 'no']
#
# # loan
# ['no' 'yes']
#
# # contact
# ['unknown' 'cellular' 'telephone']
#
# # month
# ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'jan' 'feb' 'mar' 'apr' 'sep']
#
# # poutcome
# ['unknown' 'failure' 'other' 'success']
#
# # y
# ['no' 'yes']

# %%
data.y.value_counts()
# Out:
# no     39922
# yes     5289
# Name: y, dtype: int64

# %%
a = data.y.value_counts()
print("{0:.2f}% of users didnt subscribe".format( a[0] *100 /data.shape[0]) )
print("{0:.2f}% of users subscribed".format( a[1] *100 /data.shape[0]) )
# Out:
# 88.30% of users didnt subscribe
# 11.70% of users subscribed

# %%
sns.countplot(x='y', data=data)

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder, LabelBinarizer,MultiLabelBinarizer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.model_selection import cross_val_score,StratifiedKFold

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class BinaryTransformer( BaseEstimator, TransformerMixin ):
    #Class Constructor 
    def __init__(self):
        pass
    
    #Return self nothing else to do here    
    def fit( self, X, y = None ):
        return self 
    
    #Method that describes what we need this transformer to do
    def transform( self, X, y = None ):
        self.columns = list(X.columns)
        result = X.copy()
        for c in result.columns:
            result[c] = result[c].apply(lambda x: 1 if x=="yes" else 0)
            
        return result

# %%
def pre_process(data):
    #Numeric Features
    numeric_features= list(data.columns[data.dtypes == 'float64'])
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(data[numeric_features])
    scaled_data = pd.DataFrame(data=scaled_data, columns=numeric_features)

    #Binary Features
    binary_features = ["default", "housing", "loan", "y"]
    lb = BinaryTransformer()
    binarised_features = lb.fit_transform(data[binary_features])

    # Multioutput Features
    categorical_features = list(set(list(data.columns[data.dtypes == 'object'])) - set(binarised_features))
    ohe_data = pd.get_dummies(data[categorical_features])
    new_categorical_features = ohe_data.columns

    cleaned_data = pd.concat([scaled_data, binarised_features, ohe_data], axis=1)
    
    return cleaned_data

# %%
cleaned_data = pre_process(data)

X = cleaned_data.drop('y', axis=1)
y = cleaned_data['y']

# %%
#Plotting the Cumulative Summation of the Explained Variance
pca = PCA().fit(cleaned_data)

plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') #for each component
plt.title('Pulsar Dataset Explained Variance')
plt.show()

# %%
pca = PCA(n_components=32)
X = pca.fit_transform(X)
print(X.shape)


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)
# Out:
# (45211, 32)

# %%
X
# Out:
# array([[-0.28399133,  1.54634976, -1.184906  , ...,  0.11736806,
#         -0.02662963, -0.00637164],
#        [-0.22299752, -0.33203484, -1.21933442, ...,  0.26278541,
#         -0.04816215, -0.00637674],
#        [-0.23841797, -0.8098553 , -1.1253264 , ..., -0.07171238,
#          0.03085648,  0.00749843],
#        ...,
#        [ 1.70572847,  3.45388001, -0.0638591 , ...,  0.16773637,
#         -0.28011201,  0.59267019],
#        [-0.69044348,  1.30078272, -0.07052903, ..., -0.19737116,
#         -0.29264498,  0.17575764],
#        [ 4.01681908,  0.31715394,  1.09784082, ...,  0.12224866,
#         -0.27106857,  0.84540627]])

# %% [markdown]
# ### SVC - GridSearchCV

# %%
# svc = svm.SVC(gamma="scale")


# parameters = {'kernel':('linear', 'rbf'), 'C':[1, 10]}
# svc_cv = GridSearchCV(svc, parameters, cv=5, n_jobs = -1)
# svc_cv.fit(X,y)

# %%
# clf.best_params_

# %%
svc = svm.SVC(C=1, cache_size=200, class_weight="balanced", coef0=0.0,
  decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
  max_iter=-1, probability=True, random_state=None, shrinking=True,
  tol=0.001, verbose=False)

skf = StratifiedKFold(n_splits=3, random_state=True, shuffle=True)
scores = cross_validate(svc, X, y, cv=skf, n_jobs=-1, scoring=["accuracy","recall", "precision",'f1', "roc_auc"])
for key, value in scores.items():
    print("{}: {}".format(key, value.mean()))
# Out:
# fit_time: 227.1810921827952
# score_time: 19.777403513590496
# test_accuracy: 0.8013757883113493
# train_accuracy: 0.8026143985320164
# test_recall: 0.8317262242389866
# train_recall: 0.8343732274532049
# test_precision: 0.35221843253677987
# train_precision: 0.3541458452069591
# test_f1: 0.4948658405753588
# train_f1: 0.49724008983676965
# test_roc_auc: 0.888171029313131
# train_roc_auc: 0.8893998336589523

# %%
svc.fit(X_train,y_train)
print("model score: %.3f" % svc.score(X_test, y_test))
# Out:
# model score: 0.810

# %% [markdown]
# ## Export Model

# %%
import pickle
filename = 'svc.pkl'
pickle.dump(svc, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open("svc.pkl", 'rb'))
result = loaded_model.predict([X_test[1]])
print(result)
# Out:
# [0]

# %%
X_test[0]
# Out:
# array([-0.9682888 ,  0.87239831,  1.49712393, -0.17924915, -0.93425819,
#        -1.11759235, -0.25255321,  0.31856297,  0.00977019,  0.17381663,
#         0.74075697, -0.08732605, -0.29984187, -0.01098601, -0.14032236,
#        -0.1015136 ,  0.56408909,  0.27909822,  0.26039726, -0.03867434,
#        -0.26760664,  0.26447036,  0.38688895, -0.00819016])

# %%
# Out:
# model score: 0.801

# %%
from sklearn.metrics import classification_report, f1_score, accuracy_score, precision_score, recall_score, roc_auc_score
y_pred = svc.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.80      0.88      7985
#            1       0.35      0.82      0.49      1058
#
#    micro avg       0.80      0.80      0.80      9043
#    macro avg       0.66      0.81      0.68      9043
# weighted avg       0.90      0.80      0.83      9043

# %%
from sklearn.metrics import classification_report, f1_score, accuracy_score, precision_score, recall_score, roc_auc_score
print(accuracy_score(y_test,y_pred))
print(precision_score(y_test,y_pred))
print(recall_score(y_test,y_pred))
print(f1_score(y_test,y_pred))
print(roc_auc_score(y_test,y_pred))
# Out:
# 0.801172177374765
# 0.3509266720386785
# 0.8232514177693762
# 0.492090395480226
# 0.8107490651777376

# %%
def evaluate(X_test, y_yest):
        print("#######  EVALUATED ###########")
        y_pred = svc.predict(X_test)
        acc =accuracy_score(y_test,y_pred)
        prec =precision_score(y_test,y_pred)
        rec= recall_score(y_test,y_pred)
        f1 = f1_score(y_test,y_pred)
        auc = roc_auc_score(y_test,y_pred)

        return acc,prec,rec,f1,auc
    
acc,prec,rec,f1,auc =  evaluate(X_test, y_test)
# Out:
# #######  EVALUATED ###########

# %%
X
# Out:
# array([[-0.28399133,  1.54634976, -1.184906  , ...,  0.11736806,
#         -0.02662963, -0.00637164],
#        [-0.22299752, -0.33203484, -1.21933442, ...,  0.26278541,
#         -0.04816215, -0.00637674],
#        [-0.23841797, -0.8098553 , -1.1253264 , ..., -0.07171238,
#          0.03085648,  0.00749843],
#        ...,
#        [ 1.70572847,  3.45388001, -0.0638591 , ...,  0.16773637,
#         -0.28011201,  0.59267019],
#        [-0.69044348,  1.30078272, -0.07052903, ..., -0.19737116,
#         -0.29264498,  0.17575764],
#        [ 4.01681908,  0.31715394,  1.09784082, ...,  0.12224866,
#         -0.27106857,  0.84540627]])

# %% [markdown]
# ### Random Forest Classifier - GridSearchCV

# %%
from sklearn.ensemble import RandomForestClassifier

param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}

# Create a based model
rf = RandomForestClassifier()

# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 3, n_jobs = -1, verbose = 2)

grid_search.fit(X,y)

# %%
grid_search.best_estimator_

# %%
rfc = RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=100, max_features=2, max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=5, min_samples_split=12,
            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
            oob_score=False, random_state=None, verbose=0,
            warm_start=False)

scores = cross_val_score(rfc, X, y, cv=5, n_jobs=-1, scoring='f1_macro')
scores.mean()

# %%
rfc.fit(X_train,y_train)
print("model score: %.3f" % rfc.score(X_test, y_test))

# %% [markdown]
# ### Gradient Boosting- GridSearchCV

# %%
from sklearn.ensemble import GradientBoostingClassifier  #GBM algorithm
from sklearn import cross_validation, metrics   #Additional scklearn functions
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 12, 4

# %%
def modelfit(alg, dtrain, predictors, performCV=True, printFeatureImportance=True, cv_folds=5):
    #Fit the algorithm on the data
    alg.fit(dtrain[predictors], dtrain['Disbursed'])
        
    #Predict training set:
    dtrain_predictions = alg.predict(dtrain[predictors])
    dtrain_predprob = alg.predict_proba(dtrain[predictors])[:,1]
    
    #Perform cross-validation:
    if performCV:
        cv_score = cross_validation.cross_val_score(alg, dtrain[predictors], dtrain['Disbursed'], cv=cv_folds, scoring='roc_auc')
    
    #Print model report:
    print ("\nModel Report")
    print ("Accuracy : %.4g" % metrics.accuracy_score(dtrain['Disbursed'].values, dtrain_predictions))
    print ("AUC Score (Train): %f" % metrics.roc_auc_score(dtrain['Disbursed'], dtrain_predprob))
    
    if performCV:
        print ("CV Score : Mean - %.7g | Std - %.7g | Min - %.7g | Max - %.7g" % (np.mean(cv_score),np.std(cv_score),np.min(cv_score),np.max(cv_score)))
        
    #Print Feature Importance:
    if printFeatureImportance:
        feat_imp = pd.Series(alg.feature_importances_, predictors).sort_values(ascending=False)
        feat_imp.plot(kind='bar', title='Feature Importances')
        plt.ylabel('Feature Importance Score')

# %% [markdown]
# #### Baseline

# %%
predictors = [x for x in train.columns if x not in [target, IDcol]]
gbm0 = GradientBoostingClassifier(random_state=10)
modelfit(gbm0, train, predictors)

# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("data/bank-full.csv", sep=";")
data.shape
# Out:
# (45211, 17)

# %%
data.isnull().any()
# Out:
# age          False
# job          False
# marital      False
# education    False
# default      False
# balance      False
# housing      False
# loan         False
# contact      False
# day          False
# month        False
# duration     False
# campaign     False
# pdays        False
# previous     False
# poutcome     False
# y            False
# dtype: bool

# %%
data.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       -1.000000      0.000000
# max      871.000000    275.000000

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
for c in data.columns:
    if data[c].dtype == "object":
        print("#",c)
        print(data[c].unique())
        print("")
# Out:
# # job
# ['management' 'technician' 'entrepreneur' 'blue-collar' 'unknown'
#  'retired' 'admin.' 'services' 'self-employed' 'unemployed' 'housemaid'
#  'student']
#
# # marital
# ['married' 'single' 'divorced']
#
# # education
# ['tertiary' 'secondary' 'unknown' 'primary']
#
# # default
# ['no' 'yes']
#
# # housing
# ['yes' 'no']
#
# # loan
# ['no' 'yes']
#
# # contact
# ['unknown' 'cellular' 'telephone']
#
# # month
# ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'jan' 'feb' 'mar' 'apr' 'sep']
#
# # poutcome
# ['unknown' 'failure' 'other' 'success']
#
# # y
# ['no' 'yes']

# %%
data.y.value_counts()
# Out:
# no     39922
# yes     5289
# Name: y, dtype: int64

# %%
a = data.y.value_counts()
print("{0:.2f}% of users didnt subscribe".format( a[0] *100 /data.shape[0]) )
print("{0:.2f}% of users subscribed".format( a[1] *100 /data.shape[0]) )
# Out:
# 88.30% of users didnt subscribe
# 11.70% of users subscribed

# %%
sns.countplot(x='y', data=data)

# %% [markdown]
# # Pre-Processing

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn import svm

# %%
# We create the preprocessing pipelines for both numeric and categorical data.
numeric_features = ["age","balance","day","duration","campaign","pdays","previous"]
categorical_features = set(data.columns) - set(numeric_features)

numeric_features= list(data.columns[data.dtypes == 'int64'])
categorical_features = list(data.columns[data.dtypes == 'object'])

numeric_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder())
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# Append classifier to preprocessing pipeline.
# Now we have a full prediction pipeline.
clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', svm.SVC(kernel='linear'))])

# %%
X = data.drop('y', axis=1)
y = data['y']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
clf.fit(X_train, y_train)
print("model score: %.3f" % clf.score(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-3888e9132200> in <module>()
#       3
#       4 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# ----> 5 clf.fit(X_train, y_train)
#       6 print("model score: %.3f" % clf.score(X_test, y_test))
#
# ~\Anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     263             This estimator
#     264         """
# --> 265         Xt, fit_params = self._fit(X, y, **fit_params)
#     266         if self._final_estimator is not None:
#     267             self._final_estimator.fit(Xt, y, **fit_params)
#
# ~\Anaconda3\lib\site-packages\sklearn\pipeline.py in _fit(self, X, y, **fit_params)
#     228                 Xt, fitted_transformer = fit_transform_one_cached(
#     229                     cloned_transformer, Xt, y, None,
# --> 230                     **fit_params_steps[name])
#     231                 # Replace the transformer of the step with the fitted
#     232                 # transformer. This is necessary when loading the transformer
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\memory.py in __call__(self, *args, **kwargs)
#     340
#     341     def __call__(self, *args, **kwargs):
# --> 342         return self.func(*args, **kwargs)
#     343
#     344     def call_and_shelve(self, *args, **kwargs):
#
# ~\Anaconda3\lib\site-packages\sklearn\pipeline.py in _fit_transform_one(transformer, X, y, weight, **fit_params)
#     612 def _fit_transform_one(transformer, X, y, weight, **fit_params):
#     613     if hasattr(transformer, 'fit_transform'):
# --> 614         res = transformer.fit_transform(X, y, **fit_params)
#     615     else:
#     616         res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py in fit_transform(self, X, y)
#     445         self._validate_transformers()
#     446         self._validate_column_callables(X)
# --> 447         self._validate_remainder(X)
#     448
#     449         result = self._fit_transform(X, y, _fit_transform_one)
#
# ~\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py in _validate_remainder(self, X)
#     299         cols = []
#     300         for columns in self._columns:
# --> 301             cols.extend(_get_column_indices(X, columns))
#     302         remaining_idx = sorted(list(set(range(n_columns)) - set(cols))) or None
#     303
#
# ~\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py in _get_column_indices(X, key)
#     655             columns = list(key)
#     656
# --> 657         return [all_columns.index(col) for col in columns]
#     658     else:
#     659         raise ValueError("No valid specification of the columns. Only a "
#
# ~\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py in <listcomp>(.0)
#     655             columns = list(key)
#     656
# --> 657         return [all_columns.index(col) for col in columns]
#     658     else:
#     659         raise ValueError("No valid specification of the columns. Only a "
#
# ValueError: 'y' is not in list

# %%
X_train
# Out:
#        age            job   marital  education default  balance housing loan  \
# 18647   49     technician  divorced  secondary      no     2677     yes  yes
# 5480    53         admin.   married  secondary      no     -375     yes   no
# 23864   35     technician    single   tertiary      no       33      no   no
# 3155    49    blue-collar   married    primary      no      953     yes   no
# 22261   52     management   married   tertiary      no      291      no   no
# 38581   44       services    single  secondary      no      532     yes   no
# 12855   38      housemaid  divorced  secondary      no      216      no   no
# 88      46     management  divorced  secondary      no       16     yes  yes
# 16097   37     management   married   tertiary      no      347     yes   no
# 31359   30     management    single   tertiary      no      201     yes   no
# 41848   50     management   married   tertiary      no      469      no   no
# 34019   31     technician   married  secondary      no      477      no   no
# 10051   39    blue-collar    single  secondary      no      653      no   no
# 17528   47       services   married  secondary      no     3333     yes  yes
# 24277   58     management   married   tertiary      no     2764      no   no
# 7806    37     technician   married  secondary      no     -403     yes   no
# 32912   29         admin.    single  secondary      no     3432     yes   no
# 17328   28     technician    single  secondary      no      -97      no   no
# 16710   39    blue-collar   married    unknown      no        0      no   no
# 37083   35    blue-collar   married  secondary      no      625      no   no
# 4433    36     unemployed   married  secondary      no      733     yes   no
# 26131   58    blue-collar   married  secondary      no     1507     yes  yes
# 36350   42    blue-collar   married  secondary      no     3068     yes  yes
# 33999   29     technician   married   tertiary      no      534      no   no
# 2687    49     management   married   tertiary      no      735     yes   no
# 5705    44     technician  divorced  secondary      no     1262     yes   no
# 7512    54    blue-collar   married    unknown      no     6251     yes   no
# 14408   41     technician   married  secondary     yes       -1      no   no
# 31458   33       services   married  secondary      no      260     yes   no
# 2602    40    blue-collar   married  secondary      no       59     yes   no
# ...    ...            ...       ...        ...     ...      ...     ...  ...
# 30375   45     unemployed    single  secondary      no       33      no   no
# 30508   28     technician    single   tertiary      no      676      no   no
# 1407    43    blue-collar  divorced  secondary      no      338     yes   no
# 14508   41    blue-collar   married  secondary      no      514      no  yes
# 12084   54   entrepreneur   married    unknown      no     1021      no   no
# 23210   55       services   married    unknown      no     2944      no   no
# 3178    34       services    single  secondary      no      719     yes   no
# 19889   55  self-employed   married    primary      no        0      no   no
# 13884   46    blue-collar   married    primary      no     -388     yes  yes
# 3793    56        retired   married  secondary      no     3690     yes  yes
# 26529   32     technician    single   tertiary      no      514     yes  yes
# 13170   54     management   married   tertiary      no     -547      no   no
# 7918    39    blue-collar   married    unknown      no      157     yes   no
# 20151   56        retired   married  secondary      no      646      no   no
# 3477    32       services   married  secondary      no      401     yes   no
# 20881   47      housemaid   married    primary      no      183      no   no
# 35840   42    blue-collar   married    primary      no      258     yes   no
# 8759    29     management    single   tertiary      no     1566     yes   no
# 37153   32    blue-collar    single    primary      no        7     yes   no
# 45088   38     management    single   tertiary      no     1373      no   no
# 18266   58     management   married   tertiary      no        0      no   no
# 23995   36     technician    single  secondary      no       35      no   no
# 2209    37         admin.    single  secondary      no       18      no   no
# 15083   29       services    single  secondary      no        0      no   no
# 35381   55       services   married  secondary      no        0      no   no
# 4184    28     technician    single   tertiary      no      -31     yes   no
# 2163    40       services    single  secondary      no      888     yes   no
# 27810   29    blue-collar    single  secondary      no      415      no  yes
# 11674   45    blue-collar   married    primary      no      360      no   no
# 43617   51     management    single   tertiary      no     4305     yes   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome
# 18647   cellular   31   jul        67         3     -1         0  unknown
# 5480     unknown   23   may        24         1     -1         0  unknown
# 23864   cellular   29   aug       300         2     -1         0  unknown
# 3155     unknown   14   may       278         2     -1         0  unknown
# 22261   cellular   21   aug       150         3     -1         0  unknown
# 38581   cellular   15   may       550         2    340         2  failure
# 12855   cellular    7   jul        97         3     -1         0  unknown
# 88       unknown    5   may       188         2     -1         0  unknown
# 16097   cellular   22   jul       282         1     -1         0  unknown
# 31359   cellular   17   mar       325         2     -1         0  unknown
# 41848   cellular   16   oct       170         1    183         1  success
# 34019   cellular   30   apr       146         1     -1         0  unknown
# 10051    unknown   11   jun        54         4     -1         0  unknown
# 17528   cellular   29   jul       114         2     -1         0  unknown
# 24277   cellular   17   nov       235         1     -1         0  unknown
# 7806     unknown   30   may        31         6     -1         0  unknown
# 32912   cellular   17   apr       139         2     -1         0  unknown
# 17328   cellular   28   jul        96         4     -1         0  unknown
# 16710   cellular   24   jul        90         3     -1         0  unknown
# 37083   cellular   13   may       267         1     -1         0  unknown
# 4433     unknown   20   may       335         1     -1         0  unknown
# 26131   cellular   19   nov       255         6    189         1    other
# 36350   cellular   11   may       429         2     -1         0  unknown
# 33999   cellular   30   apr       452         2     -1         0  unknown
# 2687     unknown   13   may        50         3     -1         0  unknown
# 5705     unknown   26   may       788        11     -1         0  unknown
# 7512     unknown   29   may       421         3     -1         0  unknown
# 14408   cellular   14   jul       140         2     -1         0  unknown
# 31458   cellular   31   mar       248         1     -1         0  unknown
# 2602     unknown   13   may       420         1     -1         0  unknown
# ...          ...  ...   ...       ...       ...    ...       ...      ...
# 30375   cellular    5   feb       437         1     -1         0  unknown
# 30508   cellular    5   feb      1138         2     -1         0  unknown
# 1407     unknown    8   may       116         1     -1         0  unknown
# 14508  telephone   15   jul       321         3     -1         0  unknown
# 12084    unknown   20   jun        13         7     -1         0  unknown
# 23210   cellular   27   aug       672         6     -1         0  unknown
# 3178     unknown   15   may       362         3     -1         0  unknown
# 19889   cellular    8   aug       138         2     -1         0  unknown
# 13884   cellular   10   jul       207         1     -1         0  unknown
# 3793     unknown   16   may       178         2     -1         0  unknown
# 26529   cellular   20   nov       164         1     -1         0  unknown
# 13170   cellular    8   jul       156         1     -1         0  unknown
# 7918     unknown   30   may        99         6     -1         0  unknown
# 20151   cellular   11   aug       164         2     -1         0  unknown
# 3477     unknown   15   may       294         2     -1         0  unknown
# 20881   cellular   13   aug       144         1     -1         0  unknown
# 35840   cellular    8   may        18         1    366         1  failure
# 8759     unknown    4   jun       233         1     -1         0  unknown
# 37153   cellular   13   may       109         1     -1         0  unknown
# 45088   cellular   22   oct       119         4     -1         0  unknown
# 18266   cellular   31   jul        85         4     -1         0  unknown
# 23995   cellular   29   aug       493         2     -1         0  unknown
# 2209     unknown   12   may       574         6     -1         0  unknown
# 15083   cellular   17   jul        58         1     -1         0  unknown
# 35381   cellular    7   may       110         1     -1         0  unknown
# 4184     unknown   19   may       257         1     -1         0  unknown
# 2163     unknown   12   may       169         2     -1         0  unknown
# 27810   cellular   28   jan       161         1     -1         0  unknown
# 11674    unknown   20   jun        98         2     -1         0  unknown
# 43617   cellular    4   may       126         1     -1         0  unknown
#
# [36168 rows x 16 columns]
